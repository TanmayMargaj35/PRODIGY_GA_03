# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63c85af7-4d3c-47ea-9abc-cd321f7c0298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63c85af7-4d3c-47ea-9abc-cd321f7c0298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = 'alice_in_wonderland.txt'

with open(filename, 'r', encoding='utf-8') as file:
    text = file.read()
print(text[:20000])  # Preview first 30000 characters
# Out:
# The Project Gutenberg eBook of Alice's Adventures in Wonderland
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Alice's Adventures in Wonderland
#
# Author: Lewis Carroll
#
# Release date: June 27, 2008 [eBook #11]
#                 Most recently updated: June 3, 2025
#
# Language: English
#
# Credits: Arthur DiBianca and David Widger
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***
#
# [Illustration]
#
#
#
#
# Alice’s Adventures in Wonderland
#
# by Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION 3.0
#
# Contents
#
# ...

# %%
def build_markov_chain(text, n=2):
    words = text.split()
    markov_chain = {}

    for i in range(len(words) - n):
        key = tuple(words[i:i+n])
        next_word = words[i+n]

        if key not in markov_chain:
            markov_chain[key] = []
        markov_chain[key].append(next_word)

    return markov_chain

# %%
import random

def generate_text(chain, n=2, max_words=50):
    start_key = random.choice(list(chain.keys()))
    output = list(start_key)

    for _ in range(max_words - n):
        key = tuple(output[-n:])
        next_words = chain.get(key)
        if not next_words:
            break
        next_word = random.choice(next_words)
        output.append(next_word)

    return ' '.join(output)

# %%
n = 2  # bigram model
markov_chain = build_markov_chain(text, n=n)
generated = generate_text(markov_chain, n=n, max_words=100)

# %%
import re
import textwrap

# Step 1: Split into sentences using punctuation
sentences = re.split(r'(?<=[.!?]) +', generated)

# Step 2: Combine every 2–3 sentences into one paragraph
paragraphs = []
para = ""

for i, sentence in enumerate(sentences):
    para += sentence.strip() + " "
    if (i + 1) % 3 == 0 or i == len(sentences) - 1:
        paragraphs.append(textwrap.fill(para.strip(), width=80))
        para = ""

# Step 3: Print the paragraphs like a book
for para in paragraphs:
    print("    " + para + "\n")  # Indent + new line
# Out:
#     child!” The Queen smiled and passed on. “Who _are_ you doing out here? Run home
# this moment, I tell you!” said Alice.
#
#     “Exactly so,” said the last few minutes to see it trying in a fight with another
# dig of her knowledge. “Just think of nothing better to say when I grow up, I’ll
# write one—but I’m grown up now,” she said, “than waste it in the pictures of
# him), while the Dodo in an impatient tone: “explanations take such a user who
# notifies you in writing without further opportunities to fix the problem. 1.F.4.
#
#     Except for the Dormouse,” thought
